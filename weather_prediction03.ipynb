# %% [markdown]
# <a href="https://colab.research.google.com/github/janardhankk/software-engineering---lab/blob/main/weather_prediction03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('weather_input_multiple.txt', 'r') as file:
    lines = file.readlines()
for line in lines:
    data = line.split()
    t = int(data[0])
    h = int(data[1])
    wind = int(data[2])
    w = 0.5 * (t ** 2) - (0.2 * h) + (0.1 * wind) - 15
    if w > 10:
        print("Sunny")
    elif 0 <= w <= 10:
        print("Windy")
    elif -10 <= w < 0:
        print("Cloud")
    elif w < -10:
        print("Rainy")
# Out:
# Sunny
# Sunny
# Sunny
# Sunny
# Rainy
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Sunny
# Cloud
# Sunny
# Sunny
# Sunny
